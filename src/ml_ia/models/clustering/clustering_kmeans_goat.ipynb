# %% [markdown]
# ###  Installation de l'environnement

# %%
#%pip install -r requirements.txt

# %%
# %pip install plotly-express
# Out:
# Requirement already satisfied: plotly-express in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from plotly-express) (2.3.3)
# Requirement already satisfied: plotly>=4.1.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from plotly-express) (6.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from plotly-express) (0.14.6)
# Requirement already satisfied: scipy>=0.18 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from plotly-express) (1.16.3)
# Requirement already satisfied: patsy>=0.5 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from plotly-express) (1.0.2)
# Requirement already satisfied: numpy>=1.11 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from plotly-express) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from pandas>=0.20.0->plotly-express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from pandas>=0.20.0->plotly-express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from pandas>=0.20.0->plotly-express) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from plotly>=4.1.0->plotly-express) (2.16.0)
# Requirement already satisfied: packaging in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from plotly>=4.1.0->plotly-express) (25.0)
# Requirement already satisfied: six>=1.5 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly-express) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflow keras-tuner scikit-learn pandas numpy
# Out:
# Requirement already satisfied: tensorflow in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (2.20.0)
# Requirement already satisfied: keras-tuner in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (1.4.8)
# Requirement already satisfied: scikit-learn in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: pandas in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (2.3.5)
# Requirement already satisfied: absl-py>=1.0.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: kt-legacy in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: scipy>=1.10.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from pandas) (2025.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nbformat
# Out:
# Requirement already satisfied: nbformat in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/c-enjalbert/miniconda3/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Connexion à la DB DuckDB

# %%
import duckdb
import os
from pathlib import Path
from typing import List
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from tqdm import tqdm
import sklearn
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import plotly.express as px
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm

# %% [markdown]
# ### Connexion à la DB / Import des Data

# %%
# Store database at project root
DB_NAME = Path("/home/c-enjalbert/Documents/Github/MSPR/bloc_2/amazing/amazing.duckdb") 
# Go up one level from current directory to get to project root
data_folder = Path("..") / "data"
# For absolute certainty, you could use the absolute path
# data_folder = Path("/home/c-enjalbert/Documents/EPSI/MSPR/bloc_2/amazing/data")
con = duckdb.connect(str(DB_NAME))

# %%
# 2. Query to list all tables in the database
# DuckDB specific way to list tables
tables_info = con.sql("""
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'main'
    ORDER BY table_name
""").df()

print(f"Found {len(tables_info)} tables in the database:\n")

if len(tables_info) > 0:
    for i, table_name in enumerate(tables_info['table_name']):
        print(f"{i+1}. {table_name}")
else:
    print("No tables found in the database.")
# Out:
# Found 5 tables in the database:
#
# 1. all_events
# 2. loaded_files
# 3. user_events
# 4. user_events_11_2019
# 5. user_segments_kmeans

# %% [markdown]
# ### Import de la table DuckDB

# %%
DB_NAME = "amazing.duckdb"
TABLE_EVENTS = "user_events_11_2019"
TABLE_SEGMENTS = "user_segments_11_2019"
SAMPLE_USER_PERCENT = 0.2
BATCH_SIZE = 1000

# %%
# 5. Alternative way to show all tables
print("List of all tables using DuckDB's connections.tables():")
con.sql("SHOW TABLES").show()
# Out:
# List of all tables using DuckDB's connections.tables():
# ┌──────────────────────┐
# │         name         │
# │       varchar        │
# ├──────────────────────┤
# │ all_events           │
# │ loaded_files         │
# │ user_events          │
# │ user_events_11_2019  │
# │ user_segments_kmeans │
# └──────────────────────┘

# %%
# Examine the all_events table
print(f"First 10 rows of {TABLE_EVENTS} table:")
user_events = con.sql(f"""
    SELECT * FROM {TABLE_EVENTS} ORDER BY RANDOM() LIMIT 30000
""")
user_events.show()
user_events_df = user_events.df()
# Out:
# First 10 rows of user_events_11_2019 table:
# ┌───────────┬──────────────┬─────────────┬─────────────────┬─────────────────────────┬────────────────────┬────────────────────┬─────────────────────┬──────────────────────┬──────────────────────┬───────────────────────┐
# │  user_id  │ total_events │ total_views │ total_purchases │ avg_time_between_events │    total_spent     │     avg_basket     │   last_event_time   │   conversion_rate    │    purchase_ratio    │ days_since_last_event │
# │  varchar  │    int64     │   double    │     double      │         double          │       double       │       double       │      timestamp      │        double        │        double        │         int64         │
# ├───────────┼──────────────┼─────────────┼─────────────────┼─────────────────────────┼────────────────────┼────────────────────┼─────────────────────┼──────────────────────┼──────────────────────┼───────────────────────┤
# │ 525069269 │           56 │        54.0 │             0.0 │      24866.654545454545 │                0.0 │                0.0 │ 2019-11-17 06:28:33 │                  0.0 │                  0.0 │                   135 │
# │ 530558254 │           62 │        61.0 │             0.0 │      38503.311475409835 │                0.0 │                0.0 │ 2019-11-30 12:23:33 │                  0.0 │                  0.0 │                   122 │
# │ 568114664 │           45 │        45.0 │             0.0 │       45218.61363636364 │                0.0 │                0.0 │ 2019-11-29 09:51:55 │                  0.0 │                  0.0 │                   123 │
# │ 566429227 │           13 │        10.0 │             0.0 │                106508.0 │                0.0 │                0.0 │ 2019-11-16 06:14:11 │                  0.0 │                  0.0 │                   136 │
# │ 571580432 │           21 │        21.0 │             0.0 │                 29718.8 │                0.0 │                0.0 │ 2019-11-23 07:23:50 │                  0.0 │                  0.0 │                   129 │
# │ 573736681 │           18 │        17.0 │             0.0 │      35.588235294117645 │                0.0 │                0.0 │ 2019-11-20 04:39:54 │                  0.0 │                  0.0 │                   132 │
# │ 571678225 │           14 │        14.0 │             0.0 │      201.07692307692307 │                0.0 │                0.0 │ 2019-11-15 04:41:00 │                  0.0 │                  0.0 │                   137 │
# │ 515348849 │           85 │        81.0 │             1.0 │      17650.595238095237 │              85.94 │              85.94 │ 2019-11-21 07:14:09 │ 0.012345679012345678 │ 0.012195121951219513 │                   131 │
# │ 540994913 │           19 │        17.0 │             0.0 │       32397.88888888889 │                0.0 │                0.0 │ 2019-11-18 10:09:17 │                  0.0 │                  0.0 │                   134 │
# │ 518895629 │           84 │        84.0 │             0.0 │       26001.24096385542 │                0.0 │                0.0 │ 2019-11-28 14:23:19 │                  0.0 │                  0.0 │                   124 │
# │     ·     │            · │          ·  │              ·  │               ·         │                 ·  │                 ·  │          ·          │                   ·  │                   ·  │                    ·  │
# │     ·     │            · │          ·  │              ·  │               ·         │                 ·  │                 ·  │          ·          │                   ·  │                   ·  │                    ·  │
# │     ·     │            · │          ·  │              ·  │               ·         │                 ·  │                 ·  │          ·          │                   ·  │                   ·  │                    ·  │
# │ 553464439 │           14 │        14.0 │             0.0 │       76634.23076923077 │                0.0 │                0.0 │ 2019-11-29 03:06:04 │                  0.0 │                  0.0 │                   123 │
# │ 513922056 │           33 │        33.0 │             0.0 │                2866.125 │                0.0 │                0.0 │ 2019-11-05 19:50:02 │                  0.0 │                  0.0 │                   147 │
# │ 529846524 │           14 │        13.0 │             0.0 │       7338.538461538462 │                0.0 │                0.0 │ 2019-11-17 10:55:13 │                  0.0 │                  0.0 │                   135 │
# │ 567115260 │          118 │       118.0 │             0.0 │      10429.470085470086 │                0.0 │                0.0 │ 2019-11-17 15:39:26 │                  0.0 │                  0.0 │                   135 │
# │ 571741736 │          105 │       104.0 │             0.0 │       9063.432692307691 │                0.0 │                0.0 │ 2019-11-26 07:37:47 │                  0.0 │                  0.0 │                   126 │
# │ 531741098 │           64 │        58.0 │             1.0 │      39054.857142857145 │             385.83 │             385.83 │ 2019-11-30 14:53:59 │ 0.017241379310344827 │  0.01694915254237288 │                   122 │
# │ 560009054 │           52 │        47.0 │             0.0 │       33315.19607843137 │                0.0 │                0.0 │ 2019-11-30 10:02:01 │                  0.0 │                  0.0 │                   122 │
# │ 551291166 │          146 │       129.0 │             6.0 │      14135.006896551724 │  714.0999999999999 │ 119.01666666666665 │ 2019-11-28 03:33:37 │ 0.046511627906976744 │ 0.044444444444444446 │                   124 │
# │ 522377632 │           14 │        14.0 │             0.0 │       53.92307692307692 │                0.0 │                0.0 │ 2019-11-08 08:42:13 │                  0.0 │                  0.0 │                   144 │
# │ 572714198 │           98 │        92.0 │             3.0 │      11565.443298969072 │ 30.340000000000003 │ 10.113333333333335 │ 2019-11-30 18:48:51 │  0.03260869565217391 │ 0.031578947368421054 │                   122 │
# ├───────────┴──────────────┴─────────────┴─────────────────┴─────────────────────────┴────────────────────┴────────────────────┴─────────────────────┴──────────────────────┴──────────────────────┴───────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                 11 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# Drop the datetime column
user_events_df = user_events_df.drop(columns=["last_event_time"])

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Sélectionner les features numériques uniquement
numeric_features = user_events_df.select_dtypes(include=[np.number])

# Option 1: Standardisation (Z-score normalization) - moyenne=0, écart-type=1
print("Standardisation des données...")
std_scaler = StandardScaler()
X_standardized = std_scaler.fit_transform(numeric_features)

X_num_scaled = X_standardized
# Out:
# Standardisation des données...

# %%
# Replace for Using category embeddings
#X_final = np.hstack([X_num_scaled, X_emb_scaled])
X_final = X_num_scaled  # Use scaled numerical features instead of raw dataframe

# %%
# STEP 0: Install necessary packages if not present

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras_tuner as kt
import shutil

# Clear previous tuning results to avoid shape mismatch errors
if os.path.exists('tuning_dir'):
    shutil.rmtree('tuning_dir')
    print("Cleared previous tuning results")

X_scaled = X_final 
# 2. DEFINE THE SELF-ADAPTING AUTOENCODER (SAE) - Using Functional API
def build_autoencoder(hp):
    # Input layer
    input_layer = layers.Input(shape=(X_scaled.shape[1],))
    x = input_layer
    
    # Encoder layers - Tune the number of layers and units
    for i in range(hp.Int('num_layers', 1, 3)):
        x = layers.Dense(
            units=hp.Int(f'units_{i}', min_value=16, max_value=32, step=8),
            activation='relu'
        )(x)
    
    # Latent space (The "Compressed" representation)
    latent = layers.Dense(units=hp.Int('latent_dim', 2, 10), activation='relu', name='latent_space')(x)
    
    # Decoder (mirroring the encoder)
    output = layers.Dense(X_scaled.shape[1], activation='linear')(latent)
    
    # Create model using Functional API
    model = keras.Model(inputs=input_layer, outputs=output)
    model.compile(optimizer='adam', loss='mse')
    return model

# 3. TUNE THE AUTOENCODER (Self-Adapting)
tuner = kt.RandomSearch(
    build_autoencoder,
    objective='val_loss',
    max_trials=5,
    executions_per_trial=1,
    directory='tuning_dir',
    project_name='sae_tuning'
)

print("Starting hyperparameter tuning...")
tuner.search(X_scaled, X_scaled, epochs=20, validation_split=0.2, verbose=0)
print("Tuning complete!")

best_model = tuner.get_best_models(num_models=1)[0]

# 4. EXTRACT LATENT SPACE REPRESENTATION
# We create a sub-model that stops at the 'latent_space' layer
encoder = keras.Model(inputs=best_model.input, outputs=best_model.get_layer('latent_space').output)
X_latent = encoder.predict(X_scaled, verbose=0)

print(f"Original Shape: {X_scaled.shape}")
print(f"Latent (Compressed) Shape: {X_latent.shape}")

# 5. ENSEMBLE INTERNAL VALIDATION INDEXES (IVIs)
ks = range(2, 11)
results = {
    'k': [],
    'silhouette': [],
    'calinski': [],
    'davies': []
}

for k in ks:
    kmeans = KMeans(n_clusters=k, random_state=42).fit(X_latent)
    labels = kmeans.labels_
    
    results['k'].append(k)
    results['silhouette'].append(silhouette_score(X_latent, labels))
    results['calinski'].append(calinski_harabasz_score(X_latent, labels))
    results['davies'].append(davies_bouldin_score(X_latent, labels))

res_df = pd.DataFrame(results)

# 6. THE GOATA VOTING SCHEME
# Best k is Max for Silhouette/Calinski, Min for Davies
best_k_si = res_df.loc[res_df['silhouette'].idxmax(), 'k']
best_k_ch = res_df.loc[res_df['calinski'].idxmax(), 'k']
best_k_db = res_df.loc[res_df['davies'].idxmin(), 'k']

votes = [best_k_si, best_k_ch, best_k_db]
final_k = max(set(votes), key=votes.count)

print(f"\n--- ENSEMBLE VOTES ---")
print(f"Silhouette suggests k={best_k_si}")
print(f"Calinski-Harabasz suggests k={best_k_ch}")
print(f"Davies-Bouldin suggests k={best_k_db}")
print(f"WINNING K (Optimal): {final_k}")

# 7. FINAL MODEL EXECUTION
final_kmeans = KMeans(n_clusters=int(final_k), n_init=20, random_state=42)
final_clusters = final_kmeans.fit_predict(X_latent)

# Visualizing results (using first 2 dimensions of latent space)
plt.figure(figsize=(10, 6))
plt.scatter(X_latent[:, 0], X_latent[:, 1], c=final_clusters, cmap='viridis', marker='.')
plt.title(f"Final GOATA Clustering (k={final_k}) in Latent Space")
plt.colorbar(label='Cluster ID')
plt.show()
# Out:
# Cleared previous tuning results
# Starting hyperparameter tuning...
# Tuning complete!
# /home/c-enjalbert/miniconda3/lib/python3.13/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Original Shape: (30000, 9)
# Latent (Compressed) Shape: (30000, 9)
#
# --- ENSEMBLE VOTES ---
# Silhouette suggests k=2
# Calinski-Harabasz suggests k=2
# Davies-Bouldin suggests k=2
# WINNING K (Optimal): 2

# %%
STOP
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 STOP
#
# NameError: name 'STOP' is not defined

# %%
# Fermeture de la connexion DuckDB
con.close()
