# %% [markdown]
# ###  Installation de l'environnement

# %%
# %pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] Aucun fichier ou dossier de ce nom: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Connexion à la DB DuckDB

# %%
import duckdb
import os
from pathlib import Path
from typing import List
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from tqdm import tqdm
import sklearn
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Connexion à la DB / Import des Data

# %%
# Store database at project root
DB_NAME = Path("/home/c-enjalbert/Documents/Github/MSPR/bloc_2/amazing/amazing.duckdb") 
# Go up one level from current directory to get to project root
data_folder = Path("..") / "data"
# For absolute certainty, you could use the absolute path
# data_folder = Path("/home/c-enjalbert/Documents/EPSI/MSPR/bloc_2/amazing/data")
con = duckdb.connect(str(DB_NAME))

# %%
# 2. Query to list all tables in the database
# DuckDB specific way to list tables
tables_info = con.sql("""
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'main'
    ORDER BY table_name
""").df()

print(f"Found {len(tables_info)} tables in the database:\n")

if len(tables_info) > 0:
    for i, table_name in enumerate(tables_info['table_name']):
        print(f"{i+1}. {table_name}")
else:
    print("No tables found in the database.")
# Out:
# Found 8 tables in the database:
#
# 1. all_events
# 2. loaded_files
# 3. user_events
# 4. user_events_11_2019
# 5. user_profiles
# 6. user_segments_11_2019_kmeans
# 7. user_segments_11_2019_kmeans_labeled
# 8. user_segments_kmeans

# %%
def view_table(table_name: str, limit: int = 5000):
    # Examine the all_events table
    table_data = con.sql(f"""
        SELECT * FROM {table_name}
        LIMIT {limit}
    """)
    table_data.show()

    # Show count of records in all_events
    record_count = con.sql(f"""
        SELECT COUNT(*) as total_count FROM {table_name}
    """)
    record_count.show()

    # Examine the loaded_files table
    print("\nContents of loaded_files table:")
    loaded_files_data = con.sql("""
        SELECT * FROM loaded_files
    """)
    loaded_files_data.show()

# %%
def drop_table(table_name: str) -> bool:
    
    # Drop table if it exists
    con.sql(f"DROP TABLE IF EXISTS {table_name}")

    print(f"Table {table_name} dropped")

# %%
view_table("all_events", limit=5000)
# Out:
# ┌─────────────────────┬────────────┬────────────┬─────────────────────┬────────────────────────────────┬─────────────┬─────────┬───────────┬──────────────────────────────────────┐
# │     event_time      │ event_type │ product_id │     category_id     │         category_code          │    brand    │  price  │  user_id  │             user_session             │
# │      timestamp      │  varchar   │  varchar   │       varchar       │            varchar             │   varchar   │ double  │  varchar  │               varchar                │
# ├─────────────────────┼────────────┼────────────┼─────────────────────┼────────────────────────────────┼─────────────┼─────────┼───────────┼──────────────────────────────────────┤
# │ 2019-12-01 00:00:00 │ view       │ 1005105    │ 2232732093077520756 │ construction.tools.light       │ apple       │ 1302.48 │ 556695836 │ ca5eefc5-11f9-450c-91ed-380285a0bc80 │
# │ 2019-12-01 00:00:00 │ view       │ 22700068   │ 2232732091643068746 │ NULL                           │ force       │  102.96 │ 577702456 │ de33debe-c7bf-44e8-8a12-3bf8421f842a │
# │ 2019-12-01 00:00:01 │ view       │ 2402273    │ 2232732100769874463 │ appliances.personal.massager   │ bosch       │  313.52 │ 539453785 │ 5ee185a7-0689-4a33-923d-ba0130929a76 │
# │ 2019-12-01 00:00:02 │ purchase   │ 26400248   │ 2053013553056579841 │ computers.peripherals.printer  │ NULL        │  132.31 │ 535135317 │ 61792a26-672f-4e61-9832-7b63bb1714db │
# │ 2019-12-01 00:30:56 │ view       │ 5100354    │ 2232732103101907535 │ electronics.clocks             │ suunto      │   540.3 │ 579789714 │ d27ff331-0699-4cbc-a7da-7a2670d4d77d │
# │ 2019-12-01 00:30:57 │ view       │ 53400068   │ 2053013563248739153 │ apparel.shoes                  │ NULL        │    51.1 │ 538672648 │ 17c21f84-abea-4918-b7ea-3f3827e61d64 │
# ├─────────────────────┴────────────┴────────────┴─────────────────────┴────────────────────────────────┴─────────────┴─────────┴───────────┴──────────────────────────────────────┤
# │ 5000 rows (20 shown)                                                                                                                                                  9 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌─────────────┐
# │ total_count │
# │    int64    │
# ├─────────────┤
# │   411709736 │
# └─────────────┘
#
#
# Contents of loaded_files table:
# ┌──────────────┐
# │   filename   │
# │   varchar    │
# ├──────────────┤
# │ 2019-Dec.csv │
# │ 2019-Nov.csv │
# │ 2019-Oct.csv │
# │ 2020-Apr.csv │
# │ 2020-Feb.csv │
# │ 2020-Jan.csv │
# │ 2020-Mar.csv │
# └──────────────┘

# %%
view_table("user_events")
# Out:
# ┌───────────┬──────────────┬─────────────┬─────────────────┬─────────────────────────┬────────────────────┬────────────────────┬─────────────────────┬──────────────────────┬──────────────────────┬───────────────────────┐
# │  user_id  │ total_events │ total_views │ total_purchases │ avg_time_between_events │    total_spent     │     avg_basket     │   last_event_time   │   conversion_rate    │    purchase_ratio    │ days_since_last_event │
# │  varchar  │    int64     │   double    │     double      │         double          │       double       │       double       │      timestamp      │        double        │        double        │         int64         │
# ├───────────┼──────────────┼─────────────┼─────────────────┼─────────────────────────┼────────────────────┼────────────────────┼─────────────────────┼──────────────────────┼──────────────────────┼───────────────────────┤
# │ 512985051 │           16 │        14.0 │             0.0 │                 46539.6 │                0.0 │                0.0 │ 2020-02-12 14:20:10 │                  0.0 │                  0.0 │                    48 │
# │ 519247924 │          297 │       270.0 │             6.0 │       60907.18581081081 │            3178.48 │  529.7466666666667 │ 2020-04-27 02:26:47 │ 0.022222222222222223 │ 0.021739130434782608 │                   -26 │
# │ 522919591 │           31 │        31.0 │             0.0 │      385412.93333333335 │                0.0 │                0.0 │ 2020-04-08 08:23:50 │                  0.0 │                  0.0 │                    -7 │
# │ 514531073 │          113 │        93.0 │             6.0 │              121628.625 │             460.13 │  76.68833333333333 │ 2020-04-10 18:52:13 │  0.06451612903225806 │  0.06060606060606061 │                    -9 │
# │ 514619662 │           29 │        24.0 │             1.0 │      494010.46428571426 │             158.94 │             158.94 │ 2020-03-12 10:37:46 │ 0.041666666666666664 │                 0.04 │                    19 │
# │ 567021368 │           52 │        49.0 │             0.0 │      298953.76470588235 │                0.0 │                0.0 │ 2020-04-27 18:34:29 │                  0.0 │                  0.0 │                   -26 │
# │ 517167773 │          114 │       108.0 │             2.0 │       73389.51327433628 │ 454.95000000000005 │ 227.47500000000002 │ 2020-04-30 16:26:23 │ 0.018518518518518517 │  0.01818181818181818 │                   -29 │
# │ 569853048 │           89 │        88.0 │             0.0 │               80476.125 │                0.0 │                0.0 │ 2020-01-31 18:34:38 │                  0.0 │                  0.0 │                    60 │
# │ 626411568 │           17 │        16.0 │             0.0 │              91157.5625 │                0.0 │                0.0 │ 2020-03-27 03:49:19 │                  0.0 │                  0.0 │                     4 │
# │ 519475781 │           32 │        32.0 │             0.0 │      150340.70967741936 │                0.0 │                0.0 │ 2019-12-21 12:52:45 │                  0.0 │                  0.0 │                   101 │
# │     ·     │            · │          ·  │              ·  │                  ·      │                 ·  │                 ·  │          ·          │                   ·  │                   ·  │                    ·  │
# │     ·     │            · │          ·  │              ·  │                  ·      │                 ·  │                 ·  │          ·          │                   ·  │                   ·  │                    ·  │
# │     ·     │            · │          ·  │              ·  │                  ·      │                 ·  │                 ·  │          ·          │                   ·  │                   ·  │                    ·  │
# │ 513179043 │          129 │       128.0 │             1.0 │            139298.03125 │              84.94 │              84.94 │ 2020-04-27 16:43:02 │            0.0078125 │ 0.007751937984496124 │                   -26 │
# │ 569961076 │           53 │        49.0 │             1.0 │      105974.05769230769 │              60.49 │              60.49 │ 2020-01-22 04:09:03 │  0.02040816326530612 │                 0.02 │                    69 │
# │ 637436688 │           36 │        36.0 │             0.0 │       55472.57142857143 │                0.0 │                0.0 │ 2020-04-29 00:22:35 │                  0.0 │                  0.0 │                   -28 │
# │ 577771252 │           16 │        16.0 │             0.0 │                 28567.8 │                0.0 │                0.0 │ 2019-12-02 16:05:28 │                  0.0 │                  0.0 │                   120 │
# │ 601963947 │           14 │        14.0 │             0.0 │       347634.8461538461 │                0.0 │                0.0 │ 2020-03-08 20:49:17 │                  0.0 │                  0.0 │                    23 │
# │ 564772077 │           10 │        10.0 │             0.0 │      113.11111111111111 │                0.0 │                0.0 │ 2019-10-27 17:11:12 │                  0.0 │                  0.0 │                   156 │
# │ 638753141 │           16 │        16.0 │             0.0 │      301.93333333333334 │                0.0 │                0.0 │ 2020-04-09 13:19:37 │                  0.0 │                  0.0 │                    -8 │
# │ 619004121 │          155 │       155.0 │             0.0 │       26725.29220779221 │                0.0 │                0.0 │ 2020-04-10 13:29:28 │                  0.0 │                  0.0 │                    -9 │
# │ 533560491 │           23 │        23.0 │             0.0 │       546866.7727272727 │                0.0 │                0.0 │ 2020-03-25 18:11:15 │                  0.0 │                  0.0 │                     6 │
# │ 550992970 │           24 │        24.0 │             0.0 │       583449.7391304348 │                0.0 │                0.0 │ 2020-04-28 17:27:48 │                  0.0 │                  0.0 │                   -27 │
# ├───────────┴──────────────┴─────────────┴─────────────────┴─────────────────────────┴────────────────────┴────────────────────┴─────────────────────┴──────────────────────┴──────────────────────┴───────────────────────┤
# │ 5000 rows (20 shown)                                                                                                                                                                                          11 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌─────────────┐
# │ total_count │
# │    int64    │
# ├─────────────┤
# │     5551622 │
# └─────────────┘
#
#
# Contents of loaded_files table:
# ┌──────────────┐
# │   filename   │
# │   varchar    │
# ├──────────────┤
# │ 2019-Dec.csv │
# │ 2019-Nov.csv │
# │ 2019-Oct.csv │
# │ 2020-Apr.csv │
# │ 2020-Feb.csv │
# │ 2020-Jan.csv │
# │ 2020-Mar.csv │
# └──────────────┘

# %%
drop_table("user_segments_11_2019_kmeans_labeled")
# Out:
# Table user_segments_11_2019_kmeans_labeled dropped

# %%
con.close()
